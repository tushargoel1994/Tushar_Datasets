# %%
import pandas as pd
import seaborn as sns

# %%
import pathlib
from pathlib import Path
ROOT_DIR = Path.cwd().parent
# print (ROOT_DIR)
# Out:
# c:\Users\tusha\Documents\Tushar_Datasets\1_Melb_housing_data
